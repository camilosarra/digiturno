# %%
cd Desktop\digiturno
conda activate digiturno_env
uvicorn app:socket_app --reload
# Out:
#   Cell In[1], line 1
#     cd Desktop\digiturno
#                ^
# SyntaxError: unexpected character after line continuation character
